# %%
#Dependancies
import pandas as pd
import matplotlib.pyplot as plt
from us import states
import requests
import us
from census import Census
from Config import (census_key)

# %%
### Import CDC Data

cdc_data=pd.read_csv('flupneumo.csv')

cdc_data = cdc_data.loc[cdc_data['geoid'] == "State"]

cdc_data.head()
# Out:
#    geoid  Region          State  age   season  MMWR Year/Week  \
# 0  State     NaN  New Hampshire  All  2017-18          201805
# 1  State     NaN  New York City  All  2015-16          201629
# 2  State     NaN       Missouri  All  2009-10          201020
# 4  State     NaN         Kansas  All  2017-18          201820
# 5  State     NaN        Georgia  All  2009-10          201032
#
#   Deaths from influenza Deaths from pneumonia  \
# 0                   NaN                   NaN
# 1                   NaN                   NaN
# 2                   NaN                   NaN
# 4                   NaN                   NaN
# 5                   NaN                   NaN
#
#   Deaths from pneumonia and influenza All Deaths  \
# 0                                  28        286
# 1                                  64        972
# 2                                  84        984
# 4                                  19        496
# 5                                  89      1,283
#
#    Pecent of deaths due to pneumonia or influenza  pecent complete
# 0                                        9.790210       143.277643
# 1                                        6.584362        97.618498
# 2                                        8.536585        93.231242
# 4                                        3.830645       105.194581
# 5                                        6.936867        94.671638

# %%
### Import Census Data
c = Census(census_key, year=2017)
census_data = c.acs5.get(("B19013_001E", "B01003_001E"), {'for': 'state:*'})
census_pd = pd.DataFrame(census_data)

census_pd['state name'] = census_pd['state'].apply(us.states.lookup)

census_pd
# Out:
#     B19013_001E  B01003_001E state            state name
# 0       19775.0    3468963.0    72           Puerto Rico
# 1       46472.0    4850771.0    01               Alabama
# 2       76114.0     738565.0    02                Alaska
# 3       53510.0    6809946.0    04               Arizona
# 4       43813.0    2977944.0    05              Arkansas
# 5       67169.0   38982847.0    06            California
# 6       65458.0    5436519.0    08              Colorado
# 7       73781.0    3594478.0    09           Connecticut
# 8       77649.0     672391.0    11  District of Columbia
# 9       63036.0     943732.0    10              Delaware
# 10      50883.0   20278447.0    12               Florida
# 11      52977.0   10201635.0    13               Georgia
# 12      74923.0    1421658.0    15                Hawaii
# 13      50985.0    1657375.0    16                 Idaho
# 14      61229.0   12854526.0    17              Illinois
# 15      52182.0    6614418.0    18               Indiana
# 16      56570.0    3118102.0    19                  Iowa
# 17      55477.0    2903820.0    20                Kansas
# 18      46535.0    4424376.0    21              Kentucky
# 19      53024.0    1330158.0    23                 Maine
# 20      46710.0    4663461.0    22             Louisiana
# 21      74167.0    6789319.0    25         Massachusetts
# 22      78916.0    5996079.0    24              Maryland
# 23      52668.0    9925568.0    26              Michigan
# 24      65699.0    5490726.0    27             Minnesota
# 25      42009.0    2986220.0    28           Mississippi
# 26      51542.0    6075300.0    29              Missouri
# 27      50801.0    1029862.0    30               Montana
# 28      56675.0    1893921.0    31              Nebraska
# 29      71305.0    1331848.0    33         New Hampshire
# 30      55434.0    2887725.0    32                Nevada
# 31      76475.0    8960161.0    34            New Jersey
# 32      46718.0    2084828.0    35            New Mexico
# 33      62765.0   19798228.0    36              New York
# 34      50320.0   10052564.0    37        North Carolina
# 35      61285.0     745475.0    38          North Dakota
# 36      52407.0   11609756.0    39                  Ohio
# 37      49767.0    3896251.0    40              Oklahoma
# 38      56119.0    4025127.0    41                Oregon
# 39      56951.0   12790505.0    42          Pennsylvania
# 40      61043.0    1056138.0    44          Rhode Island
# 41      48781.0    4893444.0    45        South Carolina
# 42      54126.0     855444.0    46          South Dakota
# 43      48708.0    6597381.0    47             Tennessee
# 44      57051.0   27419612.0    48                 Texas
# 45      65325.0    2993941.0    49                  Utah
# 46      57808.0     624636.0    50               Vermont
# 47      68766.0    8365952.0    51              Virginia
# 48      44061.0    1836843.0    54         West Virginia
# 49      66174.0    7169967.0    53            Washington
# 50      60938.0     583200.0    56               Wyoming
# 51      56759.0    5763217.0    55             Wisconsin

# %%
### Question 1 - Which flu season had the most deaths

# %%
### Question 2 - Which states have the highest rate of death by flu and influenza

# %%
### Question 3 - Compare death rate to population by state

# %%
### Question 4 - Compare death rate to average household income by state
